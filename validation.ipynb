# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# %%
# Визначаємо шляхи
base_path = 'C:/Users/MSI/Documents/MachineLearning/Butterfly_Classification/trainC'
validation_path = 'C:/Users/MSI/Documents/MachineLearning/Butterfly_Classification/validation'

# Отримуємо назви всіх видів
species_names = os.listdir(base_path)

# Список для відстеження всіх зображень та їхніх назв
all_images = []
all_labels = []

#Словники для підрахунку слів
species_counts_before = {}  
species_counts_after = {}   

for species in species_names:
    species_folder = os.path.join(base_path, species)
    species_images = [os.path.join(species_folder, img) for img in os.listdir(species_folder)]
    
    species_counts_before[species] = len(species_images)
    
    all_images.extend(species_images)
    all_labels.extend([species] * len(species_images))

# Розділяємо дані на набори для навчання та перевірки
train_images, validation_images, _, _ = train_test_split(all_images, all_labels, test_size=0.1, stratify=all_labels)

# Переміщаємо зобреження до папки для перевірки, з розбиттям на папки по класах
for image_path in validation_images:
    species = os.path.basename(os.path.dirname(image_path))
    dest_folder = os.path.join(validation_path, species)
    
    #Створюємо папку для класу якщо вона не існує
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    dest_path = os.path.join(dest_folder, os.path.basename(image_path))
    shutil.move(image_path, dest_path)
    
    # Підраховуємо скільки зображень ми перемістили для кожного класу
    species_counts_after[species] = species_counts_after.get(species, 0) + 1

print("Moved validation images!")

print("\nSpecies Counts Before Splitting:")
for species, count in species_counts_before.items():
    print(f"{species}: {count} images")

print("\nSpecies Counts After Moving to Validation:")
for species, count in species_counts_after.items():
    print(f"{species}: {count} images")
# Out:
# Moved validation images!
#
# Species Counts Before Splitting:
# ADONIS: 156 images
# AFRICAN GIANT SWALLOWTAIL: 156 images
# AMERICAN SNOOT: 156 images
# AN 88: 156 images
# APPOLLO: 156 images
# ARCIGERA FLOWER MOTH: 156 images
# ATALA: 156 images
# ATLAS MOTH: 156 images
# BANDED ORANGE HELICONIAN: 156 images
# BANDED PEACOCK: 156 images
# BANDED TIGER MOTH: 156 images
# BECKERS WHITE: 156 images
# BIRD CHERRY ERMINE MOTH: 156 images
# BLACK HAIRSTREAK: 156 images
# BLUE MORPHO: 156 images
# BLUE SPOTTED CROW: 156 images
# BROOKES BIRDWING: 156 images
# BROWN ARGUS: 156 images
# BROWN SIPROETA: 156 images
# CABBAGE WHITE: 156 images
# CAIRNS BIRDWING: 156 images
# CHALK HILL BLUE: 156 images
# CHECQUERED SKIPPER: 156 images
# CHESTNUT: 156 images
# CINNABAR MOTH: 156 images
# CLEARWING MOTH: 156 images
# CLEOPATRA: 156 images
# CLODIUS PARNASSIAN: 156 images
# CLOUDED SULPHUR: 156 images
# COMET MOTH: 156 images
# COMMON BANDED AWL: 156 images
# COMMON WOOD-NYMPH: 156 images
# COPPER TAIL: 156 images
# CRECENT: 156 images
# CRIMSON PATCH: 156 images
# DANAID EGGFLY: 156 images
# EASTERN COMA: 156 images
# EASTERN DAPPLE WHITE: 156 images
# EASTERN PINE ELFIN: 156 images
# ELBOWED PIERROT: 156 images
# EMPEROR GUM MOTH: 156 images
# GARDEN TIGER MOTH: 156 images
# GIANT LEOPARD MOTH: 156 images
# GLITTERING SAPPHIRE: 156 images
# GOLD BANDED: 156 images
# GREAT EGGFLY: 156 images
# GREAT JAY: 156 images
# GREEN CELLED CATTLEHEART: 156 images
# GREEN HAIRSTREAK: 156 images
# GREY HAIRSTREAK: 156 images
# HERCULES MOTH: 156 images
# HUMMING BIRD HAWK MOTH: 156 images
# INDRA SWALLOW: 156 images
# IO MOTH: 156 images
# IPHICLUS SISTER: 156 images
# JULIA: 156 images
# LARGE MARBLE: 156 images
# LUNA MOTH: 156 images
# MADAGASCAN SUNSET MOTH: 156 images
# MALACHITE: 156 images
# MANGROVE SKIPPER: 156 images
# MESTRA: 156 images
# METALMARK: 156 images
# MILBERTS TORTOISESHELL: 156 images
# MONARCH: 156 images
# MOURNING CLOAK: 156 images
# OLEANDER HAWK MOTH: 156 images
# ORANGE OAKLEAF: 156 images
# ORANGE TIP: 156 images
# ORCHARD SWALLOW: 156 images
# PAINTED LADY: 156 images
# PAPER KITE: 156 images
# PEACOCK: 156 images
# PINE WHITE: 156 images
# PIPEVINE SWALLOW: 156 images
# POLYPHEMUS MOTH: 156 images
# POPINJAY: 156 images
# PURPLE HAIRSTREAK: 156 images
# PURPLISH COPPER: 156 images
# QUESTION MARK: 156 images
# RED ADMIRAL: 156 images
# RED CRACKER: 156 images
# RED POSTMAN: 156 images
# RED SPOTTED PURPLE: 156 images
# ROSY MAPLE MOTH: 156 images
# SCARCE SWALLOW: 156 images
# SILVER SPOT SKIPPER: 156 images
# SIXSPOT BURNET MOTH: 156 images
# SLEEPY ORANGE: 156 images
# SOOTYWING: 156 images
# SOUTHERN DOGFACE: 156 images
# STRAITED QUEEN: 156 images
# TROPICAL LEAFWING: 156 images
# TWO BARRED FLASHER: 156 images
# ULYSES: 156 images
# VICEROY: 156 images
# WHITE LINED SPHINX MOTH: 156 images
# WOOD SATYR: 156 images
# YELLOW SWALLOW TAIL: 156 images
# ZEBRA LONG WING: 156 images
#
# Species Counts After Moving to Validation:
# GREAT EGGFLY: 16 images
# ELBOWED PIERROT: 16 images
# BANDED ORANGE HELICONIAN: 15 images
# GREEN HAIRSTREAK: 15 images
# ATALA: 15 images
# CAIRNS BIRDWING: 16 images
# YELLOW SWALLOW TAIL: 16 images
# GOLD BANDED: 16 images
# LUNA MOTH: 16 images
# WOOD SATYR: 16 images
# PINE WHITE: 16 images
# PAPER KITE: 15 images
# MALACHITE: 16 images
# AFRICAN GIANT SWALLOWTAIL: 16 images
# ARCIGERA FLOWER MOTH: 16 images
# PIPEVINE SWALLOW: 15 images
# METALMARK: 16 images
# POPINJAY: 16 images
# BLUE MORPHO: 15 images
# COMMON BANDED AWL: 15 images
# EASTERN DAPPLE WHITE: 15 images
# BROWN SIPROETA: 16 images
# BANDED TIGER MOTH: 16 images
# COPPER TAIL: 16 images
# QUESTION MARK: 16 images
# RED ADMIRAL: 16 images
# APPOLLO: 16 images
# AMERICAN SNOOT: 16 images
# CLEARWING MOTH: 15 images
# CLODIUS PARNASSIAN: 15 images
# DANAID EGGFLY: 16 images
# MILBERTS TORTOISESHELL: 15 images
# BROOKES BIRDWING: 16 images
# BLACK HAIRSTREAK: 15 images
# COMMON WOOD-NYMPH: 16 images
# PAINTED LADY: 15 images
# GARDEN TIGER MOTH: 16 images
# EMPEROR GUM MOTH: 16 images
# SOOTYWING: 15 images
# ZEBRA LONG WING: 16 images
# CLOUDED SULPHUR: 16 images
# IPHICLUS SISTER: 15 images
# ORCHARD SWALLOW: 16 images
# ATLAS MOTH: 15 images
# CABBAGE WHITE: 15 images
# GREEN CELLED CATTLEHEART: 15 images
# ULYSES: 16 images
# GLITTERING SAPPHIRE: 16 images
# MOURNING CLOAK: 16 images
# GIANT LEOPARD MOTH: 16 images
# GREY HAIRSTREAK: 15 images
# BIRD CHERRY ERMINE MOTH: 15 images
# BANDED PEACOCK: 15 images
# BROWN ARGUS: 16 images
# WHITE LINED SPHINX MOTH: 16 images
# PURPLISH COPPER: 16 images
# SCARCE SWALLOW: 16 images
# HERCULES MOTH: 15 images
# JULIA: 16 images
# SIXSPOT BURNET MOTH: 16 images
# MADAGASCAN SUNSET MOTH: 16 images
# BLUE SPOTTED CROW: 15 images
# IO MOTH: 16 images
# EASTERN COMA: 16 images
# RED SPOTTED PURPLE: 15 images
# MANGROVE SKIPPER: 15 images
# SLEEPY ORANGE: 16 images
# ORANGE OAKLEAF: 16 images
# CHALK HILL BLUE: 15 images
# CHESTNUT: 16 images
# OLEANDER HAWK MOTH: 15 images
# COMET MOTH: 16 images
# MONARCH: 16 images
# CINNABAR MOTH: 15 images
# ROSY MAPLE MOTH: 15 images
# VICEROY: 16 images
# SILVER SPOT SKIPPER: 16 images
# LARGE MARBLE: 16 images
# PEACOCK: 15 images
# TWO BARRED FLASHER: 15 images
# INDRA SWALLOW: 15 images
# BECKERS WHITE: 16 images
# GREAT JAY: 15 images
# CHECQUERED SKIPPER: 15 images
# SOUTHERN DOGFACE: 16 images
# ORANGE TIP: 16 images
# EASTERN PINE ELFIN: 15 images
# POLYPHEMUS MOTH: 16 images
# CRIMSON PATCH: 15 images
# RED POSTMAN: 16 images
# HUMMING BIRD HAWK MOTH: 16 images
# STRAITED QUEEN: 15 images
# CLEOPATRA: 16 images
# AN 88: 16 images
# MESTRA: 15 images
# TROPICAL LEAFWING: 15 images
# CRECENT: 16 images
# RED CRACKER: 16 images
# PURPLE HAIRSTREAK: 15 images
# ADONIS: 16 images
